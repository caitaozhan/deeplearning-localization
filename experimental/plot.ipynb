# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.rcParams['font.weight'] = 'bold'
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['font.size'] = 20

# %% [markdown]
# # Assumption:

# %%
print(np.loadtxt('regression5.txt', delimiter=','))
# Out:
# [[0.39608494 0.24690728]
#  [0.62580281 0.41840749]
#  [2.21717205 3.82563394]
#  [2.04063294 2.9924814 ]
#  [4.02987381 4.79142084]]
# [0.4350094  0.68501696 2.05378335 2.29306104 5.33658288]

# %%
reg  = np.loadtxt('regression5.txt', delimiter=',')
tran = np.loadtxt('translation2.txt', delimiter=',')
print(reg)
print()
print(tran)
# Out:
# [[0.39608494 0.24690728]
#  [0.62580281 0.41840749]
#  [2.21717205 3.82563394]
#  [2.04063294 2.9924814 ]
#  [4.02987381 4.79142084]]
#
# [[0.85122106 0.79045664]
#  [1.27065985 1.05457269]
#  [2.042949   1.34989189]
#  [2.15450686 1.35447914]
#  [2.4873002  1.48464268]]

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.plot(reg[:,0], linewidth=3, marker='o', label='Regression')
plt.plot(tran[:,0], linewidth=3, marker='^', label='Translation')
ax.set_yticks(list(range(6)))
ax.set_xticks([0, 1, 2, 3, 4])
ax.set_xticklabels([1, 0.1, 0.01, 0.005, 0.001])
ax.legend()
ax.set_xlabel('Percentage of Full Training data (10 sample at 10K locations)')
ax.set_ylabel('Localizatoin Error (10 meters)')
ax.set_title('Single TX')
# Out:
# Text(0.5, 1.0, 'Single TX')

# %% [markdown]
# Training:
# 0.1  -- 10 samples at 1K random locations
# 0.01 -- 10 samples at 100 random locations
# 0.005 -- 5 samples at 100 random locations
# 0.001 -- 2 samples at 50 random locations
#
# Testing:
# 2 samples at all 10K locations
