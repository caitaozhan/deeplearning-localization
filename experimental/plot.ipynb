# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.rcParams['font.weight'] = 'bold'
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['font.size'] = 20

# %%
reg = np.loadtxt('regression.txt')
seg = np.loadtxt('segmentation.txt')
reg, seg
# Out:
# (array([ 0.57154403,  0.93053163,  2.70590216,  5.1234911 , 26.56553923]),
#  array([0.96854667, 1.07405391, 1.37275535, 1.4320178 , 1.59149204]))

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.plot(reg, linewidth=3, marker='o', label='Regression')
plt.plot(seg, linewidth=3, marker='^', label='Segmentation')
ax.set_xticks([0, 1, 2, 3, 4])
ax.set_xticklabels([1, 0.1, 0.01, 0.005, 0.001])
ax.legend()
ax.set_xlabel('Percentage of Full Training data (10 sample at 10K locations)')
ax.set_ylabel('Localizatoin Error (10 meters)')
# Out:
# Text(0, 0.5, 'Localizatoin Error (10 meters)')

# %% [markdown]
# Training:
# 0.1  -- 10 samples at 1K random locations
# 0.01 -- 10 samples at 100 random locations
# 0.005 -- 5 samples at 100 random locations
# 0.001 -- 2 samples at 50 random locations
#
# Testing:
# 2 samples at all 10K locations
