# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams['font.size'] = 30
# plt.rcParams['font.weight'] = 'bold'
# plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['lines.linewidth'] = 5
plt.rcParams['lines.markersize'] = 10

# %%
# filter = 5

test_errors = np.loadtxt('result/2TX-20-min-dist/test_errors.txt')
test_misses = np.loadtxt('result/2TX-20-min-dist/test_misses.txt')
test_falses = np.loadtxt('result/2TX-20-min-dist/test_falses.txt')

fit, axs = plt.subplots(1, 3, figsize=(30, 8))
axs[0].plot(test_errors[1:, 0])
axs[0].set_title('2TX Localize error')
axs[0].set_ylabel('1 cell is 10m')
axs[0].set_xticks(range(9))
axs[0].set_xlabel('epoch')

axs[1].plot(test_misses[1:, 0])
axs[1].set_xticks(range(9))
axs[1].set_title('Miss counts')
axs[1].set_xlabel('epoch')

axs[2].plot(test_falses[1:, 0])
axs[2].set_title('False counts')
axs[2].set_xticks(range(9))
axs[2].set_xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# filter = 7

test_errors = np.loadtxt('result/2TX-20-min-dist-filter7/test_errors.txt')
test_misses = np.loadtxt('result/2TX-20-min-dist-filter7/test_misses.txt')
test_falses = np.loadtxt('result/2TX-20-min-dist-filter7/test_falses.txt')

fit, axs = plt.subplots(1, 3, figsize=(30, 8))
axs[0].plot(test_errors[1:, 0])
axs[0].set_title('2TX Localize error')
axs[0].set_ylabel('1 cell is 10m')
axs[0].set_xticks(range(9))
axs[0].set_xlabel('epoch')

axs[1].plot(test_misses[1:, 0])
axs[1].set_xticks(range(9))
axs[1].set_title('Miss counts')
axs[1].set_xlabel('epoch')

axs[2].plot(test_falses[1:, 0])
axs[2].set_title('False counts')
axs[2].set_xticks(range(9))
axs[2].set_xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
test_misses
# Out:
# array([[0.02106253, 0.02143603],
#        [0.01258514, 0.0084931 ],
#        [0.01038305, 0.00709052],
#        [0.0087666 , 0.00579966],
#        [0.00765203, 0.00522409],
#        [0.00677483, 0.00461298],
#        [0.00652456, 0.00442916],
#        [0.00599376, 0.00404441],
#        [0.00603116, 0.00383321],
#        [0.00568036, 0.00355349]])

# %%
test_errors = np.loadtxt('result/2TX-20-min-dist-uniformnorm/test_errors.txt')
test_misses = np.loadtxt('result/2TX-20-min-dist-uniformnorm/test_misses.txt')
test_falses = np.loadtxt('result/2TX-20-min-dist-uniformnorm/test_falses.txt')

fit, axs = plt.subplots(1, 3, figsize=(30, 8))
axs[0].plot(test_errors[1:, 0])
axs[0].set_title('2TX Localize error \n(min dist = 20)')
axs[0].set_ylabel('1 cell is 10m')
axs[0].set_xticks(range(9))
axs[0].set_xlabel('epoch')

axs[1].plot(test_misses[1:, 0])
axs[1].set_xticks(range(9))
axs[1].set_title('Miss counts')
axs[1].set_xlabel('epoch')

axs[2].plot(test_falses[1:, 0])
axs[2].set_title('False counts')
axs[2].set_xticks(range(9))
axs[2].set_xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')
